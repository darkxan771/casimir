# %%
import sys
sys.path.insert(0, "../src/")
from hypocasimir import *

# %%
P = Partition([5, 3, 3, 2, 1, 1, 1])
S = Signature([5,3,3,2,1,1,1,0,-2,-2,-4])

# %%
P.draw()

# %%
S.draw()

# %%
G = LieGroup("SU", 5)
X = SymmetricSpace("SU/SO", 5)
G.description
# Out:
# 'Special Unitary Group SU(5)'

# %%
X.description
# Out:
# 'Space of real structures SU(5)/SO(5)'

# %%
P = Partition([5,3,2])
P.dimension(G)
# Out:
# 2700

# %%
P.casimir(G)
# Out:
# -22/5

# %%
P.highest_K_type(X)
# Out:
# [5, 3]

# %%
P.hypocasimir(X)
# Out:
# -9/5
